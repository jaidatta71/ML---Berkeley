# %% [markdown]
# <a href="https://colab.research.google.com/github/jaidatta71/ML---Berkeley/blob/main/colab_activity15_1_Gradient%20Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Colab Activity 15.1: Introduction to Gradient Descent
#
# **Expected Time = 60 minutes**
#
#
# This activity introduces the iterative procedure to use the derivative in finding maximum or minimum values of a function.  To begin, you will use a numeric approximation for the derivative (slope of tangent line) and write the equation for this line.  Then, you will use this line to approximate a value of the function a short distance from the point of tangency.  In the next assignment, you will repeatedly apply this operation using gradient descent to locate the minimum value of a function.
#
# #### Index
#
# - [Problem 1](#-Problem-1)
# - [Problem 2](#-Problem-2)
# - [Problem 3](#-Problem-3)
# - [Problem 4](#-Problem-4)
# - [Problem 5](#-Problem-5)

# %%
import numpy as np
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt

from scipy.optimize import minimize

# %% [markdown]
# [Back to top](#-Index)
#
# ### Problem 1
#
# #### Examining the Function
#
# To begin, define a function $f(x) = x^2$ and a domain $x = [-2, 2]$ with 100 points. Assign the domain to the variable `x`. Plot the function and identify whether a maximum or minimum value exists.
#
# HINT: To define a domain, use numpy's `linspace`.

# %%
# np.linspace?

# %%
def f(x):
  return x**2

x = np.linspace(-2,2,100)


# Answer check
plt.plot(x, f(x), label = 'f')
plt.legend();

# %% [markdown]
# [Back to top](#-Index)
#
# ### Problem 2
#
# #### Approximating the derivative
#
#
# The definition of the derivative $f'$ of a function $f$ is:
#
# $$f'(x) =  \lim_{h \to 0} \frac{f(x + h) - f(x)}{h}$$

# %% [markdown]
# Using this definition to substitute a small value for $h$ in the difference quotient we have:
#
# $$\frac{f(x + 0.0001) - f(x)}{0.0001}$$
#
# In the code cell below, define a function `df` below that takes in a value `x` and returns the value of the derivative of $f$ along $x$.

# %%
def df(x):
    return (f(x + 0.0001) - f(x))/0.0001
x = np.linspace(-2,2,100)


# Answer check
plt.plot(x, f(x), label = 'f')
plt.plot(x, df(x), label = 'df')
plt.ylim(-1, 4)
plt.axhline(color = 'black')
plt.legend();

# %% [markdown]
# [Back to top](#-Index)
#
# ### Problem 3
#
# #### Slope of tangent at $x = 1$
#
#
#
# Use the function $f(x) = x^2$ and $f'(x)$ to determine the slope of the tangent line (the value of the derivative) at $x = 1$.  Assign this as a float to `m` below.

# %%
y = f(1)
m = df(1)


# Answer check
print(f'The slope of the tangent line at x = 1 is {m: .2f}')
# Out:
# The slope of the tangent line at x = 1 is  2.00

# %% [markdown]
# [Back to top](#-Index)
#
# ### Problem 4
#
# #### Equation of tangent line at $x = 1$
#
#
#
# Now, you can use the slope found in problem 3 and the point (1, 1) to write an equation for the tangent line.  Define a function `l` below that represents this line.  Recall the point-slope form for a line is given by:
#
# $$y = m(x - x_0) + y_0$$
#
# where $m = \text{slope}$ and $(x_0, y_0) = (x, f(x))$ = (1,1).

# %%
x0 = 1
y0 = 1
def l(x):
    return m*(x - x0) + y0


# # Answer check
plt.plot(x, f(x), label = 'f')
plt.plot(x, l(x), label = 'l')
plt.plot(1, 1, 'ro')
plt.ylim(-1, 4)
plt.axhline(color = 'black')
plt.legend();

# %% [markdown]
# [Back to top](#-Index)
#
# ### Problem 5
#
# #### Use tangent line to approximate $x = 0.9$
#
#
#
# Now, use the equation of the tangent line to approximate the value of $f(x)$ at $x = 0.9$.  Compute the absolute difference between this value and the actual value of $f(0.9)$.  Assign the absolute difference between these to `error` below.

# %%
x1 = 0.9
f_prev = f(x1)
f_next = l(x1)
error = abs(f_next - f_prev)



# # Answer check
plt.plot(x, f(x), label = 'f')
plt.plot(x, l(x), label = 'l')
plt.plot(1, 1, 'ro', label = 'starting point')
plt.plot(0.9, l(0.9), 'bo', label = 'tan line approximation')
plt.ylim(0.75, 1.05)
plt.xlim(0.88, 1.01)
plt.axhline(color = 'black')
plt.legend(frameon = False);

# %% [markdown]
# # Grading by Claude - Sonnet 3.7
#
# # Grade Assessment for Colab Activity 15.1: Introduction to Gradient Descent
#
# ## Overview
# This activity introduces the fundamental concepts of gradient descent through a series of problems that build upon each other. The student was asked to work with a simple quadratic function, approximate its derivative, find tangent lines, and use them for function approximation.
#
# ## Grading Assessment
#
# ### Problem 1: Examining the Function
# The student correctly defined the function f(x) = x² and created a domain using numpy's linspace from -2 to 2 with 100 points. The plot confirms the function has a minimum at x = 0.
#
# ### Problem 2: Approximating the Derivative
# The derivative approximation function is correctly implemented using the difference quotient with a small h value (0.0001). The plot shows the linear derivative of x² which should be 2x.
#
# ### Problem 3: Slope of Tangent at x = 1
# The student correctly calculated the slope at x = 1. Since the derivative of x² is 2x, the slope at x = 1 should be 2, and the approximation appears to be very close to this value.
#
# ### Problem 4: Equation of Tangent Line at x = 1
# The student correctly implemented the point-slope form of the tangent line equation, using the point (1, 1) and the slope calculated in problem 3. The plot confirms the tangent line touches the curve at x = 1.
#
# ### Problem 5: Using Tangent Line to Approximate f(0.9)
# The student correctly used the tangent line to approximate f(0.9) and calculated the error between this approximation and the actual value of f(0.9) = 0.81. The visualization zooms in appropriately to show the approximation.
#
# ## Significance of the Learning
#
# This assignment establishes critical foundations for understanding optimization in machine learning:
#
# 1. **Numerical Differentiation**: The student learned how to approximate derivatives computationally, a key skill when working with complex functions that don't have analytical derivatives.
#
# 2. **Tangent Line Approximations**: Understanding how tangent lines can approximate a function locally is the core insight behind gradient descent.
#
# 3. **Iterative Approximation**: The exercise lays groundwork for the iterative nature of gradient descent, where each step follows the negative gradient to approach a minimum.
#
# 4. **Error Quantification**: Calculating the difference between the approximation and true value introduces error metrics that will be important for evaluating model convergence.
#
# 5. **Visualization of Calculus Concepts**: The plotting helps build intuition about the relationship between a function and its derivative.
#
# This knowledge directly prepares the student for implementing gradient descent algorithms in subsequent exercises, which are fundamental to most machine learning optimization problems including linear regression, logistic regression, and neural networks.
#
# The student has successfully completed all required components of the activity and demonstrated an understanding of the fundamental concepts behind gradient descent.
